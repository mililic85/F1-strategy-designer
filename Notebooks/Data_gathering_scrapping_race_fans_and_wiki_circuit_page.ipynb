# %%
import requests
from bs4 import BeautifulSoup
import json
from typing import List
import os
from time import sleep
import pandas as pd
import pathvalidate 
import csv
from os import listdir
from os.path import isfile, join, isdir, dirname, exists
from io import BytesIO
from PIL import Image
import wptools
import zipfile
from datetime import datetime, date, timedelta
import requests
import re
from pathvalidate import sanitize_filename

# %%
root_directory = "./notebooks"

# %%
def get_circuit_URLs(url, host)-> List[str]:
    '''
    Aimed to recover the URLs for every circuit webpage in the blog, from we want to scrap the circuit
    information
    '''
    response = requests.get(url)
    page = response.text
    
    soups = BeautifulSoup(page, "html.parser").find_all("ul", {"id":"menu-page"}) #returns a resultSet

    url_list = []
    for soup in soups:
        aes = soup.find_all("a") #keeps just "a" elements in "ul"
        for a in aes:
            
            if "Track" in a["title"]:

                url_list.append(host + a["href"])
    
    return url_list

def get_HTML_from_source(URL)-> BeautifulSoup:
    '''
    obtain data from URLs and return a BeautifulSoup object that allows you
    to parse it.
    '''
    requests.encoding = "utf-8" #based on HTML <meta> labels of race-fans web
    response = requests.get(URL)
    page = response.content
    soup = BeautifulSoup(page,"html.parser")
    return soup

def save_HTML_file_from_url(urls:List[str], root_directory=root_directory,folder_name:str="data/circuits_HTML"):
    '''
    stores data taken from an HTTP request to the url in a file
    '''
    if not os.path.exists(folder_name):
        os.makedirs(folder_name)
    
    if len(urls) == 0:
        return

    requests.encoding = "utf-8"
    
    failed_requests = []
    
    for url in urls:
        try:
            response = requests.get(url)
            file_title = [w for w in url.split("/") if w]
            with open(os.path.join(folder_name, file_title[-1] + ".HTML"), mode='wb') as file:
                file.write(response.content)

        except Exception as e:
            
            failed_requests.append(url)
            print(str(url) + ": "+ str(e))
            print("I will sleep ...")
            sleep(2)
    print(f'pending URLs: {len(failed_requests)}')
    save_HTML_file_from_url(failed_requests)


    # Save HTML to file
    
def get_HTLM_from_file(file, folder)-> BeautifulSoup:
    '''
    gather HTML text from file and return it content for future extractions
    '''
    with open(os.path.join(folder, file), encoding='latin-1') as file:
        file_value = file.read()
        soup = BeautifulSoup(file_value, "html.parser")
    
    return soup

def get_circuit_table(soup_object):
    '''
    we want to recover the `circuit table`, with the technical
    info about the circuits we would gather. 
    '''
    
    try:
        circuit_name_key = soup_object.find("h1", {"class":"entry-title"}).text
    except Exception as e:
        circuit_name_key = None
    try:
        dict_data = {}
        for data in soup_object.find_all("table", {"class": "thin"}):
            trs = data.find_all("tr")
            for tr in trs:
                tds = tr.find_all("td")

                if len(tds[0].find_all("strong")) > 0:
                    key = tds[0].text
                    dict_data[key] = {}
                elif len(tds) == 2:
                    dict_data[key][tds[0].text] = tds[1].text
    except Exception as e:
        print(f'{e}')
        dict_data = {}
    return circuit_name_key,dict_data

def build_data(urls):
    '''for url list provided, it parses the html file to recover the technical data related circuits and save it to json file'''
    prepared_data = dict()
    for url in urls:
        try:
            title, data = get_circuit_table(url)
            prepared_data[title] = data
        except Exception as e:
            print(f"fail on {url}")
            print(e)
            print("="*50)
    print(f"success in {len(prepared_data)} urls")
    return prepared_data

def save_to_json(data):
    with open("sample.json", "w") as outfile:
        json.dump(data, outfile, indent=4)

# %% [markdown]
# ## Obtaining circuits information programatically

# %%
base_url="https://www.racefans.net/f1-information/going-to-a-race/"
host= "https://www.racefans.net"
urls = get_circuit_URLs(base_url, host)
#print(urls)

save_HTML_file_from_url(urls)

# %% [markdown]
# results of execution after about 10 mins of execution

# %%
files = os.listdir(os.path.join(root_directory, "data/circuits_HTML"))
print(len(files))

circuits = []
for url in urls:
    circuit_name = [words for words in url.split("/") if words][-1] + ".HTML"
    circuits.append(circuit_name)

    if circuit_name  not in files:
        print(f"name of the circuit that was not possible to retrieve: {circuit_name}")
# Out:
# 27
# name of the circuit that was not possible to retrieve: paul-ricard.HTML

# %% [markdown]
# ## obtaining technical data from the HTML pages

# %%
files = sorted(os.listdir(os.path.join(root_directory,"data/circuits_HTML")))
soup = get_HTLM_from_file(files[0])

get_circuit_table(soup)

parsing_result = {}
for file in files:
    
    try:
        soup = get_HTLM_from_file(file)
        circuit_name, circuit_info = get_circuit_table(soup)
    except Exception as e:
        print(f"exception for {file}: {e}")
        raise e
    
    if len(circuit_info) > 0: #table technical info from circuit exists
        dict_info = {"circuit": circuit_name,
                    "circuit_info": circuit_info,
                    "scrapping_result":"Success"}
    else:
        dict_info = {"circuit": circuit_name,
                    "circuit_info": None,
                    "scrapping_result":"technical info is not informed"}
    
    parsing_result[circuit_name] = dict_info

parsing_result

import json
with open(os.path.join(root_directory, "data", "circuits_HTML", "circuit_technical_data_from_racefans_result.json"), 'w') as outfile:
    json.dump(parsing_result, outfile, indent=4, ensure_ascii=True)

# %%
sorted(urls)
# Out:
# ['https://www.racefans.net/f1-information/going-to-a-race/albert-park-melbourne-circuit-information/',
#  'https://www.racefans.net/f1-information/going-to-a-race/autodromo-hermanos-rodriguez-circuit-information/',
#  'https://www.racefans.net/f1-information/going-to-a-race/autodromo-jose-carlos-pace-carlos-pace-interlagos-circuit-information/',
#  'https://www.racefans.net/f1-information/going-to-a-race/autodromo-nazionale-monza-italy-circuit-information/',
#  'https://www.racefans.net/f1-information/going-to-a-race/bahrain-international-circuit-track-information/',
#  'https://www.racefans.net/f1-information/going-to-a-race/baku-city-circuit-track-information/',
#  'https://www.racefans.net/f1-information/going-to-a-race/buddh-international-circuit-track-information/',
#  'https://www.racefans.net/f1-information/going-to-a-race/circuit-americas-track-information/',
#  'https://www.racefans.net/f1-information/going-to-a-race/circuit-de-catalunya-barcelona-circuit-information/',
#  'https://www.racefans.net/f1-information/going-to-a-race/circuit-gilles-villeneuve-montreal-circuit-information/',
#  'https://www.racefans.net/f1-information/going-to-a-race/circuito-urbano-valencia-street-circuit-track-information/',
#  'https://www.racefans.net/f1-information/going-to-a-race/fuji-speedway-japan-circuit-information/',
#  'https://www.racefans.net/f1-information/going-to-a-race/hockenheimring-baden-wurttemberg-germany-circuit-information/',
#  'https://www.racefans.net/f1-information/going-to-a-race/hungaroring-circuit-information/',
#  'https://www.racefans.net/f1-information/going-to-a-race/istanbul-park-circuit-information/',
#  'https://www.racefans.net/f1-information/going-to-a-race/korean-international-circuit-circuit-information/',
#  'https://www.racefans.net/f1-information/going-to-a-race/monte-carlo-circuit-information/',
#  'https://www.racefans.net/f1-information/going-to-a-race/nurburgring-new-circuit-information/',
#  'https://www.racefans.net/f1-information/going-to-a-race/red-bull-ring-circuit-information/',
#  'https://www.racefans.net/f1-information/going-to-a-race/sepang-international-circuit-track-information/',
#  'https://www.racefans.net/f1-information/going-to-a-race/shanghai-international-circuit-china/',
#  'https://www.racefans.net/f1-information/going-to-a-race/silverstone-circuit-information/',
#  'https://www.racefans.net/f1-information/going-to-a-race/singapore-street-circuit/',
#  'https://www.racefans.net/f1-information/going-to-a-race/sochi-circuit-information/',
#  'https://www.racefans.net/f1-information/going-to-a-race/spa-francorchamps-circuit-information/',
#  'https://www.racefans.net/f1-information/going-to-a-race/suzuka-circuit-japan/',
#  'https://www.racefans.net/f1-information/going-to-a-race/yas-island-abu-dhabi-circuit-information/',
#  'https://www.racefans.nethttp://www.f1fanatic.co.uk/f1-information/going-to-a-race/paul-ricard/']

# %% [markdown]
# ## Circuit information loading and preparation

# %%
# circuit table info from HTML files retrieved
df =pd.read_json("./data/outputs/circuit_data_scrapping_v1.json", orient="index")
df.sort_index()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, yas_marina to zandvoort
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   type                          33 non-null     object
#  1   Lap length                    33 non-null     float64
#  2   Full throttle                 33 non-null     float64
#  3   Longest flat-out section      33 non-null     int64
#  4   Downforce level               33 non-null     int64
#  5   Gear changes per lap          27 non-null     object
#  6   Fuel use per lap              15 non-null     object
#  7   Time penalty per lap of fuel  15 non-null     object
#  8   turns                         10 non-null     float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 2.6+ KB

# %%
df["longest_flat_out/lenght"] = df.apply(lambda x: x['Longest flat-out section']/(x['Lap length']*1000), axis=1)

# %%
df.describe()
# Out:
#        Lap length  Full throttle  Longest flat-out section  Downforce level  \
# count   33.000000      33.000000                 33.000000        33.000000
# mean     5.203848      65.015152               1125.909091         3.272727
# std      0.725212       9.814279                301.170152         0.977008
# min      3.337000      45.000000                669.000000         1.000000
# 25%      4.653000      59.000000                969.000000         3.000000
# 50%      5.400000      66.000000               1073.000000         3.000000
# 75%      5.621000      70.000000               1205.000000         4.000000
# max      7.004000      84.000000               2015.000000         5.000000
#
#            turns  longest_flat_out/lenght
# count  10.000000                33.000000
# mean   17.300000                 0.216985
# std     4.877385                 0.048624
# min    13.000000                 0.129175
# 25%    14.250000                 0.183482
# 50%    15.000000                 0.207259
# 75%    18.250000                 0.256283
# max    27.000000                 0.334833

# %%
df.rename(columns={"Lap length": "lap_lenght", "Full throttle": "full_throttle", "Longest flat-out section":"longest_straight","Downforce level":"downforce_level", "longest_flat_out/lenght": "longest_straight/lap"}, inplace=True)

# %%
df['longest_straight'] = df.apply(lambda x: x['longest_straight']/1000, axis=1) # pass longitud to km

# %%
#saving the info of interest
df = df[["type", "lap_lenght", 'full_throttle', "longest_straight",'downforce_level',"longest_straight/lap"]]

# %%
df.shape
# Out:
# (33, 6)

# %%
df.to_csv("./data/outputs/final_circuit_data_output.csv")

# %% [markdown]
# ## circuit images from wikipedia

# %%
csv_data_directory = os.path.join(root_directory, "data", "csv_ergast_data")
circuit_df = pd.read_csv(csv_data_directory + "/circuits.csv")
dir_path = os.path.join(root_directory, "data", "circuit_images")
if not os.path.exists(dir_path):
    os.makedirs(dir_path)

# %%
from io import BytesIO
import io
page = wptools.page('Nivelles-Baulers', silent=True).get()

img=page.data["image"][0]['url']
print(img)
image_file_format = img.split(".")[-1]
circuit_image = requests.get(img).content
#b = BytesIO(circuit_image)
#i = Image.open(b)
            
##i = Image.open(BytesIO(circuit_image))
#i.save(os.path.join(dir_path, 'Nivelles-Baulers' + "." + image_file_format))
with open(os.path.join(dir_path, 'Nivelles-Baulers' + "." + image_file_format), mode='wb') as file:
    
    file.write(circuit_image)
#Image.open(BytesIO(requests.get(img).content))
# Out:
# https://upload.wikimedia.org/wikipedia/commons/0/0f/Circuit_Nivelles-Baulers.png

# %%
circuit_df = pd.read_csv(os.path.join(csv_data_directory, "circuits.csv"))
circuit_df
# Out:
#     circuitId   circuitRef                                  name  \
# 0           1  albert_park        Albert Park Grand Prix Circuit
# 1           2       sepang          Sepang International Circuit
# 2           3      bahrain         Bahrain International Circuit
# 3           4    catalunya        Circuit de Barcelona-Catalunya
# 4           5     istanbul                         Istanbul Park
# ..        ...          ...                                   ...
# 72         75     portimao    Autódromo Internacional do Algarve
# 73         76      mugello  Autodromo Internazionale del Mugello
# 74         77       jeddah               Jeddah Corniche Circuit
# 75         78       losail          Losail International Circuit
# 76         79        miami         Miami International Autodrome
#
#         location       country       lat        lng  alt  \
# 0      Melbourne     Australia -37.84970  144.96800   10
# 1   Kuala Lumpur      Malaysia   2.76083  101.73800   18
# 2         Sakhir       Bahrain  26.03250   50.51060    7
# 3       Montmeló         Spain  41.57000    2.26111  109
# 4       Istanbul        Turkey  40.95170   29.40500  130
# ..           ...           ...       ...        ...  ...
# 72      Portimão      Portugal  37.22700   -8.62670  108
# 73       Mugello         Italy  43.99750   11.37190  255
# 74        Jeddah  Saudi Arabia  21.63190   39.10440   15
# 75     Al Daayen         Qatar  25.49000   51.45420   \N
# 76         Miami           USA  25.95810  -80.23890   \N
#
#                                                   url
# 0   http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1   http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2   http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3   http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 4          http://en.wikipedia.org/wiki/Istanbul_Park
# ..                                                ...
# 72  http://en.wikipedia.org/wiki/Algarve_Internati...
# 73       http://en.wikipedia.org/wiki/Mugello_Circuit
# 74  http://en.wikipedia.org/wiki/Jeddah_Street_Cir...
# 75  http://en.wikipedia.org/wiki/Losail_Internatio...
# 76  http://en.wikipedia.org/wiki/Miami_Internation...
#
# [77 rows x 9 columns]

# %% [markdown]
# ## Obtaining circuit images from wikipedia

# %% [markdown]
# By the use of URLs in table circuits, I developed a programatic backup of circuit figures from wikipedia, for future use

# %% [markdown]
# ### correction of URLs

# %% [markdown]
# Some URLS were bad encoded and errors happened during the request process, therefore, I developed a programatic and reproducible way of correct the wrong characters

# %%
root_directory = "/Users/mililic/Documents/UMA_big_data/TFM/my_TFM/notebooks"
csv_data_directory = os.path.join(root_directory, "data", "csv_ergast_data")

# Extract all contents from zip file

def df_from_zip_file(zipfile_name, data_directory = csv_data_directory):
    
    try:
        with zipfile.ZipFile(csv_data_directory + zipfile_name, 'r') as myzip:
            data=myzip.read("circuits.csv").decode(encoding="utf-8")
    
    except zipfile.BadZipFile as error:
        print(error)

    df = pd.read_csv(csv_data_directory + "/circuits.csv", encoding='utf-8')
    return df

def correct_URLs_from_circuit_df(circuit_df, to_save_file_name, save_to_data_directory = csv_data_directory):

    replacement_dict = {r'(.*)Aut%C3%B3dromo(.*)':r'\1Autódromo\2', r'(.*)Rodr%C3%ADguez(.*)':r'\1Rodríguez\2', r"(.*)N%C3%BCrburgring(.*)": r"\1Nürburgring\2",
                        r'(.*)G%C3%A1lvez(.*)': r'\1Gálvez\2', r'(.*)Montju%C3%AFc(.*)':r'\1Montjuïc\2', r'(.*)Jos%C3%A9(.*)': r'\1José\2'}

    circuit_df.url.replace(to_replace=replacement_dict, regex=True, inplace=True)
    circuit_df.to_csv(os.path.join(save_to_data_directory,to_save_file_name))
    return circuit_df

def get_circuit_images_from_wiki(df, folder_name:str="circuit_images"):
    
    # creates dir if dir does not exist
    dir_path = os.path.join(root_directory, "data", folder_name)
    if not os.path.exists(dir_path):
        os.makedirs(dir_path)
    
    image_df_list = []
    image_errors = {}
    headers = {'User-Agent': 'My User Agent 1.0'}
    for index in range(len(df)):
        
        try:
            circuit_name = df.loc[index,"url"].split("/")[-1]
            circuit_id = df.loc[index,"circuitId"]
            page = wptools.page(circuit_name, silent=True).get()
            images = page.data['image']
            circuit_image_URL = images[0]["url"]
            image_file_format = circuit_image_URL.split(".")[-1]
            circuit_image = requests.get(circuit_image_URL,headers).content
            
            if image_file_format == "svg": #saved as binary
                with open(os.path.join(dir_path, circuit_name + "." + image_file_format), mode='wb') as file:
                    
                    file.write(circuit_image)
            
            elif image_file_format == "png":
                b = BytesIO(circuit_image)
                i = Image.open(b)
                i.save(os.path.join(dir_path, circuit_name + "." + image_file_format))
            
            image_df_list.append({"circuitId": circuit_id,
                                    'circuit_name': circuit_name,
                                    'circuit_image_url': circuit_image_URL})
        
        except Exception as e:

            print(str(circuit_id) + "_" + circuit_name + ": " + str(e))
            image_errors[str(circuit_id) + "_" + circuit_name] = images
            
    img_df = pd.DataFrame(image_df_list, columns=["circuitId",'circuit_name','circuit_image_url'])
    return image_errors, img_df

# %%
circuits_df = df_from_zip_file('/f1db_csv.zip')
# correct URL names:
circuits_df = correct_URLs_from_circuit_df(circuit_df, "circuits_OK.csv", save_to_data_directory = csv_data_directory)
circuits_df
# Out:
#     circuitId   circuitRef                                  name  \
# 0           1  albert_park        Albert Park Grand Prix Circuit
# 1           2       sepang          Sepang International Circuit
# 2           3      bahrain         Bahrain International Circuit
# 3           4    catalunya        Circuit de Barcelona-Catalunya
# 4           5     istanbul                         Istanbul Park
# ..        ...          ...                                   ...
# 72         75     portimao    Autódromo Internacional do Algarve
# 73         76      mugello  Autodromo Internazionale del Mugello
# 74         77       jeddah               Jeddah Corniche Circuit
# 75         78       losail          Losail International Circuit
# 76         79        miami         Miami International Autodrome
#
#         location       country       lat        lng  alt  \
# 0      Melbourne     Australia -37.84970  144.96800   10
# 1   Kuala Lumpur      Malaysia   2.76083  101.73800   18
# 2         Sakhir       Bahrain  26.03250   50.51060    7
# 3       Montmeló         Spain  41.57000    2.26111  109
# 4       Istanbul        Turkey  40.95170   29.40500  130
# ..           ...           ...       ...        ...  ...
# 72      Portimão      Portugal  37.22700   -8.62670  108
# 73       Mugello         Italy  43.99750   11.37190  255
# 74        Jeddah  Saudi Arabia  21.63190   39.10440   15
# 75     Al Daayen         Qatar  25.49000   51.45420   \N
# 76         Miami           USA  25.95810  -80.23890   \N
#
#                                                   url
# 0   http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1   http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2   http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3   http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 4          http://en.wikipedia.org/wiki/Istanbul_Park
# ..                                                ...
# 72  http://en.wikipedia.org/wiki/Algarve_Internati...
# 73       http://en.wikipedia.org/wiki/Mugello_Circuit
# 74  http://en.wikipedia.org/wiki/Jeddah_Street_Cir...
# 75  http://en.wikipedia.org/wiki/Losail_Internatio...
# 76  http://en.wikipedia.org/wiki/Miami_Internation...
#
# [77 rows x 9 columns]

# %% [markdown]
# * If you try next cell, can take about 4 minutes, depending on your pc

# %%
errors, img_df = get_circuit_images_from_wiki(circuits_df)
# Out:
# 15_Marina_Bay_Street_Circuit: cannot identify image file <_io.BytesIO object at 0x7fcc51791ef0>
# 80_Las_Vegas_Grand_Prix#Circuit: cannot identify image file <_io.BytesIO object at 0x7fcc301404f0>
# 24_Yas_Marina_Circuit: cannot identify image file <_io.BytesIO object at 0x7fcc28451b30>
# 25_Autódromo_Oscar_Alfredo_Gálvez: https://en.wikipedia.org/w/api.php?action=query&exintro&formatversion=2&inprop=url|watchers&list=random&pithumbsize=240&pllimit=500&ppprop=disambiguation|wikibase_item&prop=extracts|info|links|pageassessments|pageimages|pageprops|pageterms|redirects&redirects&rdlimit=500&rnlimit=1&rnnamespace=0&titles=Aut%C3%B3dromo%20Oscar%20y%20Juan%20G%C3%A1lvez&plcontinue=1403866|0|San_Martín_Palace
# 28_TI_Circuit: cannot identify image file <_io.BytesIO object at 0x7fcc517bb950>
# 30_Kyalami: cannot identify image file <_io.BytesIO object at 0x7fcc20d07f90>
# 36_Autódromo_Internacional_Nelson_Piquet: cannot identify image file <_io.BytesIO object at 0x7fcc60597c20>
# 39_Circuit_Zandvoort: cannot identify image file <_io.BytesIO object at 0x7fcc403abcc0>
# 44_Las_Vegas_Street_Circuit: cannot identify image file <_io.BytesIO object at 0x7fcc518b5bd0>
# 50_Nivelles-Baulers: cannot identify image file <_io.BytesIO object at 0x7fcc517adef0>
# 51_Charade_Circuit: cannot identify image file <_io.BytesIO object at 0x7fcc70acee00>
# 54_Circuit_de_la_Sarthe#Bugatti_Circuit: cannot identify image file <_io.BytesIO object at 0x7fcc608648b0>
# 55_Reims-Gueux: cannot identify image file <_io.BytesIO object at 0x7fcc5170f220>
# 57_Zeltweg_Airfield: cannot identify image file <_io.BytesIO object at 0x7fcc20d2ac20>
# 65_Pescara_Circuit: cannot identify image file <_io.BytesIO object at 0x7fcc607d9e50>
# 67_Pedralbes_Circuit: cannot identify image file <_io.BytesIO object at 0x7fcc51715ae0>
# 71_Sochi_Autodrom: cannot identify image file <_io.BytesIO object at 0x7fcc607d9400>

# %% [markdown]
# Most of the errors were from *png> I was researching about that, but given most of the images were recovered, I will comeback for specific
# image if I dont have it after this process.

# %%
img_df
# Out:
#     circuitId                     circuit_name  \
# 0           1     Melbourne_Grand_Prix_Circuit
# 1           2     Sepang_International_Circuit
# 2           3    Bahrain_International_Circuit
# 3           4   Circuit_de_Barcelona-Catalunya
# 4           5                    Istanbul_Park
# 5           6                Circuit_de_Monaco
# 6           7        Circuit_Gilles_Villeneuve
# 7           8    Circuit_de_Nevers_Magny-Cours
# 8           9              Silverstone_Circuit
# 9          10                   Hockenheimring
# 10         11                      Hungaroring
# 11         12          Valencia_Street_Circuit
# 12         13     Circuit_de_Spa-Francorchamps
# 13         14        Autodromo_Nazionale_Monza
# 14         16                    Fuji_Speedway
# 15         17   Shanghai_International_Circuit
# 16         18       Autódromo_José_Carlos_Pace
# 17         19      Indianapolis_Motor_Speedway
# 18         20                      Nürburgring
# 19         21    Autodromo_Enzo_e_Dino_Ferrari
# 20         22                   Suzuka_Circuit
# 21         26     Circuito_Permanente_de_Jerez
# 22         27             Autódromo_do_Estoril
# 23         29          Adelaide_Street_Circuit
# 24         31                   Donington_Park
# 25         32     Autódromo_Hermanos_Rodríguez
# 26         33           Phoenix_street_circuit
# 27         34              Paul_Ricard_Circuit
# 28         35     Korean_International_Circuit
# 29         37           Detroit_street_circuit
# 30         38                     Brands_Hatch
# 31         40                           Zolder
# 32         41                    Dijon-Prenois
# 33         42                        Fair_Park
# 34         43           Long_Beach,_California
# 35         45   Circuito_Permanente_Del_Jarama
# 36         46       Watkins_Glen_International
# 37         47             Scandinavian_Raceway
# 38         48                          Mosport
# 39         49                 Montjuïc_circuit
# 40         52           Circuit_Mont-Tremblant
# 41         53                Rouen-Les-Essarts
# 42         56            Prince_George_Circuit
# 43         58     Aintree_Motor_Racing_Circuit
# 44         59             Circuito_da_Boavista
# 45         60  Riverside_International_Raceway
# 46         61                             AVUS
# 47         62            Monsanto_Park_Circuit
# 48         63                  Sebring_Raceway
# 49         64                 Ain-Diab_Circuit
# 50         66               Circuit_Bremgarten
# 51         68      Buddh_International_Circuit
# 52         69          Circuit_of_the_Americas
# 53         70                    Red_Bull_Ring
# 54         73                Baku_City_Circuit
# 55         75    Algarve_International_Circuit
# 56         76                  Mugello_Circuit
# 57         77            Jeddah_Street_Circuit
# 58         78     Losail_International_Circuit
# 59         79    Miami_International_Autodrome
#
#                                     circuit_image_url
# 0   https://upload.wikimedia.org/wikipedia/commons...
# 1   https://upload.wikimedia.org/wikipedia/commons...
# 2   https://upload.wikimedia.org/wikipedia/commons...
# 3   https://upload.wikimedia.org/wikipedia/commons...
# 4   https://upload.wikimedia.org/wikipedia/commons...
# 5   https://upload.wikimedia.org/wikipedia/commons...
# 6   https://upload.wikimedia.org/wikipedia/commons...
# 7   https://upload.wikimedia.org/wikipedia/commons...
# 8   https://upload.wikimedia.org/wikipedia/commons...
# 9   https://upload.wikimedia.org/wikipedia/commons...
# 10  https://upload.wikimedia.org/wikipedia/commons...
# 11  https://upload.wikimedia.org/wikipedia/commons...
# 12  https://upload.wikimedia.org/wikipedia/commons...
# 13  https://upload.wikimedia.org/wikipedia/commons...
# 14  https://upload.wikimedia.org/wikipedia/commons...
# 15  https://upload.wikimedia.org/wikipedia/commons...
# 16  https://upload.wikimedia.org/wikipedia/commons...
# 17  https://upload.wikimedia.org/wikipedia/commons...
# 18  https://upload.wikimedia.org/wikipedia/commons...
# 19  https://upload.wikimedia.org/wikipedia/commons...
# 20  https://upload.wikimedia.org/wikipedia/commons...
# 21  https://upload.wikimedia.org/wikipedia/commons...
# 22  https://upload.wikimedia.org/wikipedia/commons...
# 23  https://upload.wikimedia.org/wikipedia/commons...
# 24  https://upload.wikimedia.org/wikipedia/commons...
# 25  https://upload.wikimedia.org/wikipedia/commons...
# 26  https://upload.wikimedia.org/wikipedia/commons...
# 27  https://upload.wikimedia.org/wikipedia/commons...
# 28  https://upload.wikimedia.org/wikipedia/commons...
# 29  https://upload.wikimedia.org/wikipedia/commons...
# 30  https://upload.wikimedia.org/wikipedia/commons...
# 31  https://upload.wikimedia.org/wikipedia/commons...
# 32  https://upload.wikimedia.org/wikipedia/commons...
# 33  https://upload.wikimedia.org/wikipedia/commons...
# 34  https://upload.wikimedia.org/wikipedia/commons...
# 35  https://upload.wikimedia.org/wikipedia/commons...
# 36  https://upload.wikimedia.org/wikipedia/commons...
# 37  https://upload.wikimedia.org/wikipedia/commons...
# 38  https://upload.wikimedia.org/wikipedia/commons...
# 39  https://upload.wikimedia.org/wikipedia/commons...
# 40  https://upload.wikimedia.org/wikipedia/commons...
# 41  https://upload.wikimedia.org/wikipedia/commons...
# 42  https://upload.wikimedia.org/wikipedia/commons...
# 43  https://upload.wikimedia.org/wikipedia/commons...
# 44  https://upload.wikimedia.org/wikipedia/commons...
# 45  https://upload.wikimedia.org/wikipedia/commons...
# 46  https://upload.wikimedia.org/wikipedia/commons...
# 47  https://upload.wikimedia.org/wikipedia/commons...
# 48  https://upload.wikimedia.org/wikipedia/commons...
# 49  https://upload.wikimedia.org/wikipedia/commons...
# 50  https://upload.wikimedia.org/wikipedia/commons...
# 51  https://upload.wikimedia.org/wikipedia/commons...
# 52  https://upload.wikimedia.org/wikipedia/commons...
# 53  https://upload.wikimedia.org/wikipedia/commons...
# 54  https://upload.wikimedia.org/wikipedia/commons...
# 55  https://upload.wikimedia.org/wikipedia/commons...
# 56  https://upload.wikimedia.org/wikipedia/commons...
# 57  https://upload.wikimedia.org/wikipedia/commons...
# 58  https://upload.wikimedia.org/wikipedia/commons...
# 59  https://upload.wikimedia.org/wikipedia/commons...

# %% [markdown]
# ## Obtaining Grand Prix Tyres strategies information

# %% [markdown]
# ### obtain the URLs from race_fans that contains "tyres" as title

# %%
def get_tyre_strategy_URLS(date_init:date, how_many_days=365):

    url = 'https://www.racefans.net/'
    counter = 0
    tyre_related_URLS = []
    for day in range(how_many_days):

        new_day = (date_init + timedelta(day))
        d = datetime.strftime(new_day, "%Y/%m/%d/")
        r = requests.get(url + d).content
        article_titles = BeautifulSoup(r, "html.parser").find_all("h2", {"class":"entry-title"}) #article titles
        
        for title in article_titles:
            a = title.find("a")
            if a is not None:
                if "tyre" in a.text:
                    print(a.text)
                    tyre_related_URLS.append(a["href"])
            
    print(len(tyre_related_URLS))
    print(tyre_related_URLS)
    return tyre_related_URLS
    

def get_tyre_strategy_table(soup_object:BeautifulSoup):
    '''
    we want to recover the `tyre strategy table`, type of tyres and tyre changes along the
    race.
    '''
    tables = soup_object.find_all("table", {"class": "thin"})
    return_value = {}
    dict_keys = []
    for table in tables:
        scrapping_result = {}
        ths = table.find_all("th")
        
        if len(ths) !=0:
            #column headers
            dict_keys = [th.text for th in ths]
        
        body = table.find("tbody")

        if body:
            trs_in_body = body.find_all("tr")
        
            for tr in trs_in_body:

                tds_text = [td.text for td in tr.find_all("td")]

                if len(tds_text) < len(dict_keys):
                    tds_text += [None]*(len(dict_keys)-len(tds_text))
                
                json_object = {key:value for key, value in zip(dict_keys[1:], tds_text[1:])}
                
                for key, value in json_object.items():
                    json_object[key] = parse_values(key, value)

                scrapping_result[tds_text[0]] = json_object

        else:
            trs_in_body = table.find_all("tr")
        
            for tr in trs_in_body:
    
                if len(dict_keys) ==0:
                    #column headers
                    dict_keys = [td.text for td in tr.find_all("td")]
                    continue

                tds_text = [td.text for td in tr.find_all("td")]

                if len(tds_text) < len(dict_keys):
                    tds_text += [None]*(len(dict_keys)-len(tds_text))
                
                json_object = {key:value for key, value in zip(dict_keys[1:], tds_text[1:])}
                
                for key, value in json_object.items():
                    json_object[key] = parse_values(key, value)

                scrapping_result[tds_text[0]] = json_object

        
        return_value[table.previous_element] = scrapping_result
    
    return return_value

def parse_values(key:str, text:str):
    if "stint" in key.lower() and text:
        tyre_type, lap_to = split_stint(text)
        return {"tyre_type": tyre_type, "lap_to": int(lap_to)}
    return text
        

def split_stint(text):
    splited = [e.strip() for e in re.split(r'(.*)\((.*)\)', text) if e]
    if len(splited) == 1:
        splited.append(-1)
    return splited

# %%
def parse_race_name(file_name):
    name_without_year = [race for race in re.split(r'^([0-9]{4}-)+(.*)', file_name) if race][-1]
    name_without_extention = name_without_year.split('.')[0]
    return name_without_extention.replace("-", " ")
    

def parse_file(file_name, source_directory_name, target_directory_name, header):
    soup = get_HTLM_from_file(file_name, source_directory_name)
    content = get_tyre_strategy_table(soup)
    if not content:
        raise Exception("empty dict")

    #print(content)
    for key, value in content.items():
        final_target_directory = join(target_directory_name, sanitize_filename(key))
        os.makedirs(final_target_directory, exist_ok=True)

        for header_key, header_value in header.items():
            value[header_key] = header_value

        with open(join(final_target_directory, f"{file_name}.json"), 'w', encoding="utf-8") as outfile:
            json.dump(value, outfile, indent=4, ensure_ascii=False)

# %%
header = {
    "year": "2013",
    "file_name": "2013-australian-grand-prix-tyre-strategies-pit-stops.HTML",
    "race": parse_race_name("2013-australian-grand-prix-tyre-strategies-pit-stops.HTML")
}
print(header)
parse_file("2013-australian-grand-prix-tyre-strategies-pit-stops.HTML", "./data/tyre_strategy_racefans/2013_tyre_strategy", "./data/tyre_strategy_racefans/json/2013_tyre_strategy", header)
# Out:
# {'year': '2013', 'file_name': '2013-australian-grand-prix-tyre-strategies-pit-stops.HTML', 'race': 'australian grand prix tyre strategies pit stops'}

# %%
#root_directory = "./data/tyre_strategy_racefans"

source_directories = ["2015_tyre_strategy"]

source_directories = [dir for dir in listdir(root_directory) if dir != "json"]

for source in source_directories:
    source_directory = join(root_directory, source)
    dest_directory = join(root_directory, "json", source)

    for file in listdir(source_directory):
        os.makedirs(dest_directory, exist_ok=True)

        header = {
            "year": source[0:4],
            "file_name": file,
            "race": parse_race_name(file)
        }
        
        try:
            parse_file(file, source_directory, dest_directory, header)
        except ValueError as e:
            print(f"ValueError FAIL: [{join(source_directory, file)}] {e}")
        except Exception as e:
            print(f"Exception FAIL: [{join(source_directory, file)}] {e}")
# Out:
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\1410.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\178.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\2011-belgian-grand-prix-ferrari.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\2011-canadian-grand-prix-virgin.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\2011-european-grand-prix-hrt.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\2011-hungarian-grand-prix-prerace-analysis.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\2011-indian-grand-prix-practice-analysis.HTML] [WinError 3] The system cannot find the path specified: './data/tyre_strategy_racefans\\json\\2011_tyre_strategy\\ was quickest in the first session but slipped to fourth in the afternoon. He said “We looked quick this morning. This afternoon, however, I had a problem with the driveshaft óÔé¼ÔÇ£ it felt like it was causing some wear and tear so it prompted me to end'
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\2011-malaysian-grand-prix-mclaren.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\2011-monaco-grand-prix-preview.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\2011-monaco-grand-prix-second-practice-analysis-2.HTML] [WinError 3] The system cannot find the path specified: './data/tyre_strategy_racefans\\json\\2011_tyre_strategy\\Another unexpected property of the super-soft tyre was that some drivers were able to improve their times after their first lap. This could have an effect on qualifying, allowing drivers an extra chance to set a good lap if they get stuck in traffic'
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\2011-singapore-grand-prix-analysis.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\2011-spanish-grand-prix-practice-analysis.HTML] [Errno 2] No such file or directory: './data/tyre_strategy_racefans\\json\\2011_tyre_strategy\\ were outside 1.7% of Webber’s time by over a second. They will be hoping the fastest cars do not use soft tyres in Q1 or they may not qualify\\2011-spanish-grand-prix-practice-analysis.HTML.json'
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\2011-spanish-grand-prix-toro-rosso.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\223.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\26-gp2-drivers-racing-f1-star.HTML] [WinError 3] The system cannot find the path specified: './data/tyre_strategy_racefans\\json\\2011_tyre_strategy\\Russian Mikhail Aleshin was originally supposed to drive the second Carlin entry but dropped out after his funding fell through. There are reports he may have secured backing to do the first round this weekend'
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\309.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\88.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\alguersuari.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\dont-blame-pirelli-for-high-tyre-wear-wirth.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\drivers-race-soft-tyres-brazil.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\extra-tyres-teams-spa.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\ferrari-3.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\gp2-adopts-f1style-tyre-rules-points.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\hamilton-hopes-massive-degradation-means-more-pit-stops.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\hamilton-tyre-conservation-key-turkey.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\hamilton-tyres-painfully-slow.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\hard-tyres-hurting-admits-massa.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\heidfeld-r31-tyre-advantage.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\lucas-di-grassi-pirellis-official-tyre-tester.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\massa-happy-tyres-believes-red-bull-ahead.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\massa-pirelli-medium-tyre-hard-compound.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\mclaren-expecting-radical-shift-2012-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\mclaren-tyres-engine-modes-key-catching-red-bull.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\new-pirelli-medium-tyre-much-stronger-says-perez.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\new-tyres-bringin-fundamental-change-f1-2011.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\pirelli-change-tyre-markings-malaysia-china.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\pirelli-denies-claims-tyre-marbles-dangerous.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\pirelli-introduce-medium-tyres-valencia.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\pirelli-introduce-super-hard-tyre-barcelona.HTML] [WinError 3] The system cannot find the path specified: './data/tyre_strategy_racefans\\json\\2011_tyre_strategy\\The medium tyre will be used for the first time in the European Grand Prix. After Spain, the hard tyre will be used next in Silverstone, though Pirelli have not decided whether to take the original or new hard tyre'
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\pirelli-introduce-supersoft-tyres-monaco.HTML] [Errno 2] No such file or directory: './data/tyre_strategy_racefans\\json\\2011_tyre_strategy\\In Monaco they will have Pirelli’s two softest compounds soft and super-soft. The medium tyre has not yet been used in a race weekend\\pirelli-introduce-supersoft-tyres-monaco.HTML.json'
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\pirelli-plan-introduce-superhard-tyre-spain.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\pirelli-shrug-criticism-hard-tyre.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\pirelli-test-wet-tyres-at-night-in-abu-dhabi.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\pirelli-tyre-failure-vettel-retirement.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\soft-tyre-seconds-quicker-hard-india.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\sutil-overcome-tyre-problems.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\teams-test-development-tyres-fridays.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\teams-test-longer-life-medium-tyre-canada.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\time-bring-qualifying-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\vettel-surprised-race-pace-tyre-worries.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2011_tyre_strategy\we-expecting-tyres-worse-vettel.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2012_tyre_strategy\142.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2012_tyre_strategy\162.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2012_tyre_strategy\2012-bahrain-grand-prix-friday-practice-analysis.HTML] [Errno 2] No such file or directory: './data/tyre_strategy_racefans\\json\\2012_tyre_strategy\\Red Bull’s poor straight-line speed is much in evidence again – Mark Webber was only faster than the two Marussias through the speed trap\\2012-bahrain-grand-prix-friday-practice-analysis.HTML.json'
# Exception FAIL: [./data/tyre_strategy_racefans\2012_tyre_strategy\2012-german-grand-prix-tyre-strategies-pit-stops.HTML] 'NoneType' object is not callable
# Exception FAIL: [./data/tyre_strategy_racefans\2012_tyre_strategy\alguersuari-di-grassi-test-pirelli-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2012_tyre_strategy\cars-18-tyres-f1-sixwheelers-2012-goodwood-festival-speed.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2012_tyre_strategy\extra-tyres-drivers-friday-cota.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2012_tyre_strategy\f1-change-tyre-strategy.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2012_tyre_strategy\f1-fanatic-roundup-0710.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2012_tyre_strategy\f1-fanatic-roundup-078.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2012_tyre_strategy\f1-fanatic-roundup-088.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2012_tyre_strategy\f1-fanatic-roundup-16.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2012_tyre_strategy\f1-fanatic-roundup-35.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2012_tyre_strategy\f1-fix-flawed-rules-pirelli-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2012_tyre_strategy\ferrari-recruit-top-bridgestone-tyre-technician.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2012_tyre_strategy\hamilton-jenson-switch-tyres-extremely.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2012_tyre_strategy\harder-tyres-drivers-push-hard-spa-pirelli.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2012_tyre_strategy\mercedes-aim-crack-tyre-temperature-problems-china.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2012_tyre_strategy\pirelli-reveal-softer-compounds-tyre-colours-2012.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2012_tyre_strategy\pirelli-tyre-rules-bringing-uptodate.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2012_tyre_strategy\polls-show-fans-concerned-drs-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2012_tyre_strategy\teams-test-hard-tyres-silverstone.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2012_tyre_strategy\whitmarsh-wrong-criticise-tyre.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\2013-belgian-grand-prix-friday-practice-analysis.HTML] 'NoneType' object is not callable
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\2013-british-grand-prix-review.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\alonso-doubts-tyre-failures-point-to-silverstone-repeat.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\alonso-perez-tyre-failure-could-have-injured-me.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\boullier-criticises-pirelli-tyre-tweaks.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\button-expects-avoid-2012-dip-fairer-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\button-massa-current-tyres-good-f1.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\button-tyres-fundamental-performance-2013.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\di-resta-pleased-with-tyre-call-despite-missing-pole.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\drivers-concerned-extreme-tyre-degradation.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\drivers-expecting-q3-save-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\drivers-pleased-with-quick-response-to-tyre-failures.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\drs-tyres-f1-balance-2013.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\extra-friday-tyres-drivers-teams.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\extra-tyres-boost-practice-running-spain.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\f1-bungled-call-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\f1-fanatic-round-up-0107.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\f1-fanatic-round-up-0207.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\f1-fanatic-round-up-0610.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\f1-fanatic-round-up-0810.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\f1-fanatic-round-up-1106.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\f1-fanatic-round-up-1107.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\f1-fanatic-round-up-1110-2.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\f1-fanatic-round-up-1406.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\f1-fanatic-round-up-1506.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\f1-fanatic-round-up-2111.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\f1-fanatic-round-up-2408.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\f1-fanatic-round-up-2908.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\f1-fanatic-round-up-2910.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\f1-fanatic-roundup-024.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\f1-fanatic-roundup-0403.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\f1-fanatic-roundup-1805.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\f1-fanatic-roundup-2303.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\f1-fanatic-roundup-2405.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\f1-fanatic-roundup-2703.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\fair-solution-needed-for-2014-tyre-testing-brawn.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\ferrari-and-lotus-got-lucky-with-2013-tyres-newey.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\ferrari-join-lotus-criticising-tyre-rules-change.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\fia-allows-teams-to-field-race-drivers-at-young-drivers-test.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\fia-confirm-pirelli-to-continue-as-tyre-supplier.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\fia-expands-tyre-test-investigation-to-include-ferrari.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\fia-imposes-limits-on-tyre-use-to-prevent-punctures.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\gutierrez-working-tyre-management.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\hamilton-and-button-demand-change-after-tyre-explosion.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\hamilton-has-nothing-positive-to-say-about-these-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\hamilton-soft-tyre-circuit.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\hembery-pirelli-2014.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\hungary-tyre-changes-will-affect-title-battle-rosberg.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\i-got-a-pirelli-puncture-from-a-pirelli-tyre-webber.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\lotus-still-unhappy-with-conservative-tyre-choices.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\massa-unhappy-with-tyre-choice-for-final-stint.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\mclaren-expect-pirelli-to-remain-as-tyre-supplier.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\mclaren-not-expecting-pirelli-to-impose-tyre-stint-limits.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\mercedes-rivals-considering-protest-over-tyre-test.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\more-drivers-and-more-tyres-for-first-practice.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\no-change-to-canada-race-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\no-complaints-from-webber-over-tyre-strategy.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\onelap-tyres-appeal-vergne.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\perez-puncture-caused-by-cut-on-tyre-pirelli.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\pirelli-admits-it-was-wrong-to-let-teams-swap-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\pirelli-bring-tyre-canada.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\pirelli-change-tyres-latest-failure.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\pirelli-changes-tyre-allocations-for-next-three-races.HTML] [WinError 3] The system cannot find the path specified: './data/tyre_strategy_racefans\\json\\2013_tyre_strategy\\Pirelli will bring their hardest ever tyre combination for Suzuka, using the most durable compounds in their range medium and hard. At Korea – as in Singapore this weekend – the medium will be used alongside the super-soft tyre'
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\pirelli-deny-tyre-tests-favoured-any-team.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\pirelli-disappointed-teams-disobeyed-tyre-advice.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\pirelli-expects-strategy-shift-from-aggressive-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\pirelli-plan-tyre-prevent-fourstoppers.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\pirelli-swaps-soft-tyre-compound-medium-bahrain.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\pirelli-teams-support-aggressive-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\pirelli-to-use-prototype-tyres-for-german-grand-prix.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\pirelli-tyre-war-f1-paul-hembery-interview.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\pirelli-tyres-to-be-very-conservative-in-2014.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\raikkonen-suspects-sharp-kerbs-caused-tyre-failures.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\raikkonen-understand-tyre-complaints.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\red-bull-protest-mercedes-over-barcelona-tyre-test.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\red-bull-to-perform-pirelli-tyre-test-at-catalunya.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\rosberg-was-aware-what-tyres-pirelli-were-testing.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\safety-of-2014-tyres-not-in-question-pirelli.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\still-too-much-tyre-saving-for-webber.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\teams-denied-chance-to-use-2014-tyres-in-final-practice.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\teams-to-test-pirellis-2014-tyres-in-brazil.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\the-winners-and-losers-since-the-tyre-change.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\vettel-attacks-unsafe-pirelli-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\webber-wet-weather-the-condition-tyres-work-in.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2013_tyre_strategy\whitmarsh-expects-headaches-tyres-2013.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2014_tyre_strategy\2014-belgian-grand-prix-lap-charts.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2014_tyre_strategy\2014-british-grand-prix-tyre-strategies-pit-stops.HTML] [Errno 2] No such file or directory: './data/tyre_strategy_racefans\\json\\2014_tyre_strategy\\ very long pit stop was due to the fact he came into the pits when the race was red-flagged and stayed their until it resumed over an hour later\\2014-british-grand-prix-tyre-strategies-pit-stops.HTML.json'
# Exception FAIL: [./data/tyre_strategy_racefans\2014_tyre_strategy\customer-parts-tyre-warmer-ban-2015.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2014_tyre_strategy\drivers-concerned-pirellis-tyre-choices-hard.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2014_tyre_strategy\driving-without-tyre-warmers-difficult-nasr.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2014_tyre_strategy\f1-fanatic-round-3003.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2014_tyre_strategy\f1-fanatic-round-3004.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2014_tyre_strategy\f1-fanatic-round-up-1209-2.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2014_tyre_strategy\f1-fanatic-round-up-1710-3.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2014_tyre_strategy\fewer-marbles-new-tyres-pirelli.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2014_tyre_strategy\fia-pirelli-monitor-tyre-temperatures.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2014_tyre_strategy\massa-keen-see-less-conservative-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2014_tyre_strategy\mercedes-fastest-alonso-tyre-mix.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2014_tyre_strategy\pirelli-announce-tyre-choices-first-four-races.HTML] [Errno 2] No such file or directory: './data/tyre_strategy_racefans\\json\\2014_tyre_strategy\\Pirelli say the gap in performance between the three hardest tyres – the soft, medium and hard – has widened with their new 2014 compounds\\pirelli-announce-tyre-choices-first-four-races.HTML.json'
# Exception FAIL: [./data/tyre_strategy_racefans\2014_tyre_strategy\pirelli-reveal-18-inch-wheel-tyre-design-ahead-test.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2014_tyre_strategy\pirelli-test-tyre-warmer-ban-bahrain.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2014_tyre_strategy\rosberg-says-cut-chicane-avoid-tyre-damage.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2014_tyre_strategy\rosberg-surprised-high-tyre-degradation.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2014_tyre_strategy\soft-tyre-strong-call-interlagos-says-pirelli.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2014_tyre_strategy\suspended-e10000-fine-toro-rosso-tyre-error.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\dont-try-to-silence-drivers-on-tyre-safety.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\f1-fanatic-round-up-0509-3.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\f1-fanatic-round-up-0709-3.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\f1-fanatic-round-up-0809-3.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\f1-fanatic-round-up-1005.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\f1-fanatic-round-up-1611-3.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\f1-fanatic-round-up-2105.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\f1-fanatic-round-up-2412-3.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\f1-fanatic-round-up-2508-3.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\f1-fanatic-round-up-2509-3.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\f1-fanatic-round-up-3005.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\ferrari-not-at-fault-over-tyre-blow-out-vettel.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\fia-confirms-new-tyre-rules-and-virtual-safety-car-changes.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\fia-publishes-overhauled-2016-tyre-rules.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\hamilton-boosts-title-lead-as-tyre-row-erupts-at-spa.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\hamilton-confirmed-winner-after-tyre-investigation.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\hamilton-doubts-mercedes-will-solve-tyre-problems-overnight.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\hamilton-wins-as-tyre-failure-costs-vettel-third.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\hamiltons-tyre-saving-helped-raikkonen-catch-vettel.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\highly-unusual-number-of-cuts-blamed-for-spa-tyre-failures.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\michelin-vs-pirelli-which-tyres-are-right-for-f1.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\mystery-over-tyre-blow-out-is-worrying-rosberg.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\pirelli-announce-china-and-bahrain-tyre-choices.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\pirelli-confirms-12-hour-test-for-ultra-soft-tyre-debut.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\pirelli-continue-with-same-tyre-choices-for-next-races.HTML] [WinError 206] The filename or extension is too long: './data/tyre_strategy_racefans\\json\\2015_tyre_strategy\\As in 2014, F1’s official tyre supplier will bring its hardest tyre compounds for the Spanish Grand Prix, and its softest combination for Monaco, Canada and Austria'
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\pirelli-demands-more-tyre-testing-for-2017.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\pirelli-explains-how-new-tyre-rules-will-work.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\pirelli-introduce-new-super-soft-tyre-2015.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\pirelli-keeps-same-tyre-choices-for-first-four-races.HTML] [WinError 3] The system cannot find the path specified: './data/tyre_strategy_racefans\\json\\2015_tyre_strategy\\For the Malaysian Grand Prix at the Sepang International Circuit, which has more abrasive asphalt, generally higher cornering speeds and punishing temperatures, Pirelli will bring the medium and hard tyre compounds'
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\pirelli-nominates-tyres-for-first-race-of-2016.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\pirelli-says-drivers-should-be-given-maximum-stint-lengths-for-its-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\pirelli-secures-2017-19-tyre-deal.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\pirelli-selects-softer-tyres-for-italian-grand-prix.HTML] [WinError 3] The system cannot find the path specified: './data/tyre_strategy_racefans\\json\\2015_tyre_strategy\\The same tyre allocation will also be used for the races at Spa-Francorchamps and the Hungaroring. Pirelli will bring its hardest tyres for the British Grand Prix at Silverstone'
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\pirelli-to-present-result-of-vettel-tyre-investigation.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\pirellis-monza-tyre-choice-good-for-the-show.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\rosberg-blow-out-not-caused-by-tyre-problem-pirelli.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\rosberg-puzzled-by-bad-tyre-set-in-q3.HTML] [Errno 2] No such file or directory: './data/tyre_strategy_racefans\\json\\2015_tyre_strategy\\Rosberg’s radio messages after his first run in Q3 revealed his team had some indication his first set of tyres in the session would be “poor”\\rosberg-puzzled-by-bad-tyre-set-in-q3.HTML.json'
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\rosberg-rues-second-row-start-despite-better-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\rosberg-stays-ahead-before-high-speed-tyre-blowout.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\rosberg-wants-action-on-tyres-before-monza.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\should-f1-adopt-pirellis-tyre-stint-limits-plan.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\strategy-group-plans-return-of-refuelling-free-tyre-choice-and-cars-five-seconds-quicker.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\teams-barred-from-using-post-season-tyre-test-for-development.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\teams-given-strict-guideline-over-tyre-use.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\tyre-warmer-burned-raikkonens-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\vettel-furious-over-unacceptable-tyre-blow-out.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\vettels-tyre-failure-due-to-ferrari-strategy-pirelli.HTML] empty dict
# ValueError FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\williams-to-investigate-bizarre-bottas-tyre-mix-up.HTML] too many values to unpack (expected 2)
# Exception FAIL: [./data/tyre_strategy_racefans\2015_tyre_strategy\yas-marina-pirelli-tyre-test-in-pictures.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\2016-chinese-grand-prix-first-practice-result-fp1.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\2016-spanish-grand-prix-first-practice-result-fp1.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\2017-abu-dhabi-tyre-test-in-pictures.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\315123.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\318724.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\325134.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\327758.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\bodywork-caused-tyre-failures-massa.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\bottas-almost-had-same-tyre-failure-as-massa.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\button-unhappy-with-massively-high-tyre-pressures.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\cut-tyre-compromised-hamiltons-strategy.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\designed-to-degrade-vs-flat-out-f1-time-to-change-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\drivers-tyre-choices-bahrain-announced.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\drivers-tyre-choices-chinese-grand-prix-confirmed.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\drivers-tyre-choices-russia-announced.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\drivers-tyre-selections-first-race-announced.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\f1-fanatic-round-up-0701-2.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\f1-fanatic-round-up-0901-2.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\f1-fanatic-round-up-1411-4.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\f1-fanatic-round-up-1710-4.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\f1-fanatic-round-up-2010-4.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\f1-fanatic-round-up-2404-2.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\f1-fanatic-round-up-2407-3.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\f1-fanatic-round-up-2602-3.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\f1-fanatic-round-up-2701-2.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\f1-fanatic-round-up-2708-4.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\f1-fanatic-round-up-2801-2.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\f1-to-scrap-high-degradation-tyres-in-2017-pirelli.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\ferrari-chooses-softer-tyres-mercedes-spain.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\ferrari-go-aggressive-austria-tyre-choices.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\ferrari-red-bull-mercedes-conduct-2017-tyre-tests.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\fia-approves-large-increase-testing-2017-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\first-practice-red-flagged-tyre-failures.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\haas-renault-take-no-super-softs-canada.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\hamilton-rosberg-select-tyres-showdown.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\hamilton-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\hardest-tyre-selection-british-grand-prix.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\little-difference-tyre-choices-malaysia.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\long-stint-didnt-cause-vettels-tyre-blow-out-in-austria.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\mercedes-favour-harder-tyres-mexican-grand-prix.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\new-pirelli-tyres-tested-friday.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\no-hard-tyres-italian-grand-prix.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\no-ultra-soft-tyre-for-russian-grand-prix.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\pirelli-2.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\pirelli-begin-2017-tests-ferrari-fiorano.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\pirelli-begins-wet-tyre-testing-at-paul-ricard.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\pirelli-confirms-ultra-soft-tyres-monaco.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\pirelli-continue-testing-new-tyres-monza.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\pirelli-nominates-tyres-bakus-first-f1-race.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\pirelli-offer-super-soft-tyres-spa.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\pirelli-offers-ultra-soft-tyres-austrian-grand-prix.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\pirelli-reveal-wider-2017-tyres-will-look.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\pirelli-stick-hardest-tyre-selection-malaysia.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\pirelli-urges-more-tyre-testing-ahead-of-crunch-meeting-on-2017-rules.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\pirelli-wet-tyre-test-day-two-in-pictures.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\raikkonen-wehrlein-continue-2017-tyre-tests.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\red-bull-choose-harder-tyres-brazil.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\red-bull-prefer-harder-tyres-suzuka.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\red-bull-prefer-harder-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\red-bull-will-benefit-from-new-tyre-rules-newey.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\rosberg-tests-2017-tyres-cataunya.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\softer-tyres-f1s-return-mexico.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\soon-call-new-tyre-rules-success.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\super-soft-tyres-for-resurfaced-hungaroring.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\two-years-after-bianchis-crash-drivers-are-still-unhappy-with-pirellis-wet-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\tyres-used-able-handle-conditions-raikkonen.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\ultra-soft-tyre-to-debut-in-canada-not-monaco.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\ultra-soft-tyres-available-singapore.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\ultra-soft-tyres-return-final-race.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\vettel-not-blaming-ferrari-red-flag-tyre-call.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\vettel-on-top-as-two-day-wet-tyre-test-concludes.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\vettel-says-tyre-exploded-without-warning.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\wider-2017-f1-tyres-seen-first-time.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\will-f1s-last-race-on-high-degradation-tyres-serve-up-a-championship-surprise.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2016_tyre_strategy\williams-expect-tough-race-tyre-wear.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\2017-hungarian-grand-prix-friday-practice-analysis.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\2017-pre-season-testing-best-times-by-driver-and-tyre.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\2017-test-one-best-driver-times-and-tyres-used.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\343988.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\championship-contenders-pick-tyres-hungary.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\conservative-tyre-choice-mercedes-silverstone.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\damage-caused-raikkonens-tyre-failure-says-pirelli.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\drivers-asking-for-more-full-wet-tyres-for-fridays-ricciardo.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\drivers-can-go-non-stop-on-new-tyres-hembery.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\drivers-go-ultra-soft-first-tyre-choices-2017-monaco.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\drivers-tyre-choices-italy-belgium-confirmed.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\durable-ultra-softs-may-reward-unusual-strategies.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\f1-fanatic-round-up-0106-4.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\f1-fanatic-round-up-0801-3.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\f1-fanatic-round-up-1405-3.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\f1-will-not-use-hard-tyres-italian-gp-either.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\ferrari-go-aggressive-malaysia-tyre-choice.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\ferrari-go-softer-canadian-gp-tyre-choices.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\final-tyre-selections-2017-confirmed.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\grosjean-wary-of-more-aquaplaning-with-wider-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\hamilton-breaks-track-record-hardest-tyres-first-session.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\hamilton-more-consistent-tyres-fantastic-for-drivers.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\hamilton-vettel-wore-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\hamilton-wins-britain-vettel-hit-late-tyre-failure.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\harder-tyres-are-way-too-hard-ricciardo.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\hypersoft-best-tyre-pirelli-produced-hamilton.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\little-variety-azerbaijan-gp-tyre-choices.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\mclaren-make-aggressive-tyre-selection-suzuka.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\new-tyres-aero-shouldnt-harm-overtaking-hembery.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\new-tyres-double-the-fun-hulkenberg.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\new-tyres-feel-two-steps-harder-palmer.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\no-change-tyre-choices-hungarian-gp.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\no-hyper-soft-tyres-for-first-three-races.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\pireli-chooses-softest-tyres-austria.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\pirelli-announce-2018-tyre-test-schedule-involving-teams.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\pirelli-avoids-hard-tyres-british-grand-prix.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\pirelli-concerned-over-wider-wet-weather-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\pirelli-names-new-tyre-2018-hypersoft.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\pirelli-says-slow-puncture-caused-vettels-tyre-failure.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\pirelli-selects-ultra-soft-tyres-spa-francorchamps.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\pirelli-very-unlikely-to-use-backup-2016-style-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\pirellis-new-softer-tyre-2018-will-pink.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\pirellis-ultra-soft-tyres-will-pink-weekend.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\races-will-be-true-test-of-wet-tyres-hulkenberg.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\raikkonen-blames-tyres-for-stupid-qualifying-delay.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\raikkonen-wet.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\red-bull-engineer-says-tyres-are-key-to-2017-overtaking.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\red-bull-prefer-harder-tyres-mexican-gp-choices.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\renault-williams-pick-softest-tyres-brazil.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\ricciardo-frustrated-confused-tyre-warm-issues.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\sainz-feared-tyre-gamble-backfire.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\sixth-tyre-compound-and-softer-rubber-for-2018-pirelli.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2017_tyre_strategy\stroll-delayed-by-flat-spotted-tyre-after-first-corner-near-miss.HTML] empty dict
# ...
# Exception FAIL: [./data/tyre_strategy_racefans\2019_tyre_strategy\red-bull-stock-up-on-soft-tyres-for-season-finale.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2019_tyre_strategy\renault-was-the-striker-breaker-on-18-inch-pirelli-tyre-test-wolff.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2019_tyre_strategy\should-formula-1-drop-the-q3-tyre-rule.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2019_tyre_strategy\spectators-still-find-tyre-graphic-difficult-to-understand-pirellli.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2019_tyre_strategy\steiner-wants-f1-to-drop-kinder-surprise-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2019_tyre_strategy\stroll-we-made-wrong-tyre-call-four-times-out-of-five.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2019_tyre_strategy\teams-say-tyres-are-limiting-how-much-they-can-test.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2019_tyre_strategy\the-cars-are-identical-williams-suspects-tyres-explains-kubicas-deficit-to-russell.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2019_tyre_strategy\thinner-2019-tyres-not-reason-for-mercedes-success-pirelli.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2019_tyre_strategy\top-teams-make-similar-tyre-selections-for-french-gp.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2019_tyre_strategy\verstappen-poor-racing-in-f1-due-to-tyres-as-well-as-cars.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2019_tyre_strategy\verstappen-selects-more-soft-tyres-than-rivals-for-italian-gp.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2019_tyre_strategy\vettel-admits-ferrari-are-struggling-more-with-tyres-than-in-previous-years.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2019_tyre_strategy\vettel-ferrari-are-struggling-with-tyres-more-than-others.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2019_tyre_strategy\vettel-quickest-on-harder-tyres-in-first-practice.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2019_tyre_strategy\vettel-suspects-pirelli-hasnt-hit-2020-tyre-targets.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2019_tyre_strategy\why-formula-1-should-bring-back-the-tyre-war.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2019_tyre_strategy\williams-grip-no-better-even-if-we-put-rear-tyres-on-the-front-kubica.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2019_tyre_strategy\wolff-explains-decision-to-start-bottas-on-used-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2019_tyre_strategy\zandvoort-banking-will-make-tyre-pressures-painful-verstappen.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\hamilton-pirelli-must-produce-better-tyres-for-2021.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\hamilton-pirellis-new-2021-tyres-are-worse-despite-two-years-development.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\hamilton-suspects-balloon-like-tyre-pressures-contributed-to-mercedes-blistering.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\hamilton-tired-of-tyre-management-after-flawless-spanish-grand-prix-win.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\hamilton-wanted-to-start-the-race-on-medium-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\horrific-garbage-hard-tyres-may-force-drivers-onto-two-stop-strategies.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\how-f1-teams-are-adapting-last-years-chassis-as-mule-cars-for-2021-tyre-testing.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\latifis-car-felt-amazing-despite-tyre-problems.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\leclerc-surprised-and-relieved-to-qualify-fourth-on-medium-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\magnussen-retired-because-we-didnt-have-any-more-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\mazepin-scores-first-win-in-race-of-tyre-management.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\mercedes-drivers-say-silverstone-tyre-blistering-wasnt-on-our-radar-and-could-recur.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\mercedes-seek-urgent-tyre-blistering-fix-to-avoid-looking-silly-in-spain.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\new-18-inch-tyres-will-make-f1-cars-up-to-two-seconds-slower-allison.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\no-change-this-year-to-red-flag-tyre-rule-which-norris-called-stupid.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\no-link-between-mercedes-das-and-tyre-failures-says-wolff.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\one-more-lap-and-my-tyres-wouldve-exploded-perez.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\pirelli-2020-tyres-teams-rejected-would-have-coped-better-with-high-silverstone-loads.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\pirelli-begins-probe-into-verstappen-tyre-failure.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\pirelli-change-test-plans-as-18-inch-tyres-are-delayed-to-2022.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\pirelli-in-race-to-solve-tyre-troubles-after-hamiltons-three-wheeled-win.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\pirelli-learning-lessons-from-f2-tyres-for-f1s-switch-to-18-inch-rubber.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\pirelli-say-2021-tyre-test-was-positive-despite-criticism-from-hamilton-and-others.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\pirelli-say-softer-tyres-werent-their-choice-after-driver-complaints.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\pirelli-says-its-unlikely-to-race-special-zandvoort-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\pirelli-want-answers-on-silverstone-tyre-failures-by-tuesday.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\pirelli-will-use-new-rules-to-test-revised-tyres-for-2021-in-britain-and-spain.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\racing-point-believe-front-wing-damage-caused-strolls-tyre-trouble.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\red-bull-surprised-no-other-team-tried-to-qualify-on-hard-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\red-bull-suspect-debris-caused-tyre-failure-which-ended-verstappens-race.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\russell-relieved-to-understand-tyre-problem-which-compromised-race.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\russells-race-losing-tyre-mix-up-was-not-due-to-human-error-wolff.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\silverstone-restoring-becketts-kerb-to-previous-specification-following-tyre-cuts.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\slower-ferrari-only-beat-us-because-of-q3-tyre-rule-tost.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\softer-tyres-in-bahrain-may-push-teams-towards-two-stop-strategies.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\stroll-says-he-had-no-chance-to-reach-q3-on-wrong-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\teams-to-test-new-tyre-designed-for-zandvoort-banking-next-week.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\the-huge-forces-f1s-fastest-cars-ever-are-exerting-on-their-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\they-should-be-bald-hamiltons-tyre-condition-didnt-concern-mercedes.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\verstappen-at-his-irrepressible-best-as-tyres-trip-mercedes.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\verstappen-says-more-wins-will-be-difficult-with-conservative-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\verstappen-was-absolutely-right-to-overrule-call-to-save-tyres-horner.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\verstappens-tyre-had-50-cuts-in-it-horner.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\warmer-weather-for-f1s-second-race-at-silverstone.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\we-need-more-grip-and-better-safety-hamilton-puts-fresh-pressure-on-pirelli-to-improve-f1-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\why-mercedes-floundered-in-conditions-that-needed-a-car-which-kills-its-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\will-softer-rubber-make-a-thrilling-race-or-52-laps-of-tyre-management.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2020_tyre_strategy\will-softer-tyres-trouble-mercedes-again-five-belgian-gp-talking-points.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\2022-brazilian-grand-prix-interactive-data-lap-charts-times-and-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\2022-japanese-grand-prix-interactive-data-lap-charts-times-and-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\2022-mexican-grand-prix-interactive-data-lap-charts-times-and-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\2022-singapore-grand-prix-interactive-data-lap-charts-times-and-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\2022-united-states-grand-prix-interactive-data-lap-charts-times-and-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\f1-to-trial-new-mandatory-qualifying-tyre-compound-rule-in-2023.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\ferrari-cant-match-red-bulls-tyre-management-in-unexpected-situations-leclerc.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\ferrari-examining-process-which-led-to-leclerc-tyre-choice-mistake.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\ferrari-were-very-fast-but-chose-the-wrong-tyres-verstappen.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\hamilton-different-tyre-compound-at-start-could-have-helped-me-beat-verstappen.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\hamilton-wanted-to-start-mexican-grand-prix-with-different-tyre-strategy.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\hard-tyres-may-have-been-wrong-choice-for-final-attack-on-verstappen-sainz.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\hasty-tyre-blanket-ban-could-make-f1-a-worse-sport-engineers-warn.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\how-pirelli-is-addressing-the-main-limitation-verstappen-identified-with-its-2022-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\leclerc-crashes-russell-fastest-in-second-practice-dedicated-to-tyre-testing.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\leclerc-quickest-in-extended-second-practice-as-teams-test-2023-tyres.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\mclarens-leap-forward-in-melbourne-down-to-tyres-and-track-norris.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\mercedes-doubt-tyre-strategy-cost-hamilton-chance-to-beat-verstappen-to-win.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\mercedes-tyre-strategy-calls-may-have-cost-them-two-wins-in-a-row-binotto.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\one-stop-races-no-issue-if-new-tyres-improve-racing-isola.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\perez-warns-plan-to-lower-tyre-blanket-temperatures-will-put-drivers-at-risk.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\pirelli-chooses-hardest-tyres-for-first-race-and-splits-selection-for-melbourne.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\pirelli-explains-thinking-behind-step-in-melbourne-tyre-compound-choice.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\russell-has-no-regrets-over-soft-tyre-gamble-after-crash-leaves-him-eighth.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\strange-tyre-degradation-cost-red-bull-win-to-ferrari-horner.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\taller-new-f1-tyres-for-2022-make-drivers-view-more-difficult-verstappen.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\verstappen-and-stroll-confident-last-years-baku-tyre-failures-wont-recur.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\verstappen-mystified-as-tyre-woes-leave-him-fourth-on-grid-but-sees-potential-for-race.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\verstappen-out-runs-hamilton-in-tyre-management-battle-for-record-14th-win.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\verstappen-says-leclerc-ran-out-of-tyres-before-end-of-sprint-race.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\verstappen-says-soft-tyres-have-unbelievable-inconsistencies-in-grip.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\verstappen-suzuka-race-shows-we-need-better-rain-tyres-in-f1.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\verstappen-would-have-been-too-slow-even-if-hed-started-on-soft-tyre.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\we-made-it-harder-for-ourselves-with-tyre-call-says-perez-after-massive-monaco-gp-win.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\we-should-go-for-slicks-no-how-hamilton-almost-joined-russell-in-doomed-q3-tyre-gamble.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\why-ferraris-pace-may-flatter-to-deceive-and-teams-face-a-tricky-tyre-decision.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\why-motorsport-cant-afford-to-ignore-its-tyre-pollution-problem.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\2022_tyre_strategy\will-verstappens-tyre-advantage-allow-him-to-defeat-unbeatable-mercedes.HTML] empty dict
# Exception FAIL: [./data/tyre_strategy_racefans\csv\tyre_strategy.csv] empty dict

# %%
tyre_URLS = get_tyre_strategy_URLS(date_init=date(2011,1,1))

# %%
len(tyre_URLS)
# Out:
# 59

# %%
save_HTML_file_from_url(tyre_URLS, folder_name="data/tyre_strategy_racefans/2011_tyre_strategy")
# Out:
# pending URLs: 0

# %%
def parse_csv():
    root_directory = join("data","tyre_strategy_racefans","json")
    headers_to_exclude = ['year', 'file_name', 'race']
    headers = [ 'year', 'race', 'name']
    values = []

    for dir in listdir(root_directory):
        inner_dir = join(root_directory, dir, "The tyre strategies for each driver")
        if not exists(inner_dir):
            print(f'NO DIR - {inner_dir}')
            continue

        for file_name in listdir(inner_dir):
            data = json.load(open(join(inner_dir, file_name)))

            for key, value in data.items():
                if key not in headers_to_exclude:
                    try:
                        new_row = [data["year"], data["race"], key] 
                    except Exception as e:
                        print(file_name)
                        raise e

                    for i in range(1,10):
                        stint_key = f'Stint {i}'
                        stint_value = value.get(stint_key, None)
                        
                        if stint_value:
                            try:
                                add_header_if_not_exists(headers, stint_key, stint_value)
                            except Exception as e:
                                print(f'file_name - {file_name}')
                                print(f'header - {header}')
                                print(f'stint_key - {stint_key}')
                                print(f'stint_value - {stint_value}')
                                raise e
                            new_row.append(stint_value["tyre_type"])
                            new_row.append(stint_value["lap_to"])

                    values.append(new_row)
    
    return headers, values

def add_header_if_not_exists(headers:list, new_header:str, internal_value:dict):
    for key, _ in internal_value.items():
        proposed_header = f'{new_header} {key}'
        if proposed_header not in headers:
            headers.append(proposed_header)

header, data = parse_csv()
with open('data/tyre_strategy_racefans/csv/tyre_strategy.csv', 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerows(data)
# Out:
# NO DIR - data\tyre_strategy_racefans\json\2011_tyre_strategy\The tyre strategies for each driver
# NO DIR - data\tyre_strategy_racefans\json\csv\The tyre strategies for each driver

# %% [markdown]
# ### TYRE STRATEGY MERGE

# %%
tyre_strategy_pd = pd.read_csv(join("data", "tyre_strategy_racefans", "csv", "tyre_strategy.csv"))
drivers_pd = pd.read_csv(join("data", "csv_ergast_data", "drivers.csv"))
circuits_pd = pd.read_csv(join("data", "csv_ergast_data", "circuits.csv"))
races_pd = pd.read_csv(join("data", "csv_ergast_data", "races.csv"))

tyre_strategy_pd_2022 = pd.read_csv(join("data", "tyre_strategy_racefans", "csv", "2022-missing.csv"))

# %%
drivers_pd["name"] = drivers_pd["forename"] + " " + drivers_pd["surname"]

races_pd = races_pd[races_pd["year"] > 2011]
races_pd["match_country"] = races_pd["name"].str.lower()
# correct the names to same format between tables
tyre_strategy_pd.replace({'Carlos Sainz Jnr':'Carlos Sainz', 'Kimi Raikkonen': "Kimi Räikkönen",
                             "Sergio Perez": "Sergio Pérez", "Nico Hulkenberg": "Nico Hülkenberg", 
                             "Zhou Guanyu": "Guanyu Zhou", "Nyck De Vries": "Nyck de Vries",
                             "Esteban Gutierrez": "Esteban Gutiérrez", "Jean-Eric Vergne": "Jean-Éric Vergne",
                             "Jerome dâ€™Ambrosio": "Jérôme d'Ambrosio"}, inplace=True)

tyre_strategy_pd_2022["match_country"] = tyre_strategy_pd_2022["race"]
drivers_pd_2022 = drivers_pd[~drivers_pd["driverId"].isin([27, 76, 30, 818])] # drop duplicates driver codes

# %%
tyre_strategy_pd = pd.merge(tyre_strategy_pd, drivers_pd[["name", "driverId"]], how="left", on="name")
tyre_strategy_pd_2022 = pd.merge(tyre_strategy_pd_2022, drivers_pd_2022[["code", "name", "driverId"]], how="inner", on="code")

# %%
tyre_strategy_pd_2022 = tyre_strategy_pd_2022[['year', 'race', 'name', 'Stint 1 tyre_type', 'Stint 1 lap_to',
       'Stint 2 tyre_type', 'Stint 2 lap_to', 'Stint 3 tyre_type',
       'Stint 3 lap_to', 'Stint 4 tyre_type', 'Stint 4 lap_to',
       'Stint 5 tyre_type', 'Stint 5 lap_to', 'Stint 6 tyre_type',
       'Stint 6 lap_to', 'Stint 7 tyre_type', 'Stint 7 lap_to', 'driverId']]

# %%
tyre_strategy_pd = pd.concat([tyre_strategy_pd, tyre_strategy_pd_2022])
tyre_strategy_pd["match_country"] = tyre_strategy_pd["race"].str.split(" grand", expand=True)[0] + " grand prix"
tyre_strategy_pd.replace({
    'sao paulo grand prix':'são paulo grand prix', 
    'australian gp interactive data lap charts times and tyres grand prix':'australian grand prix'}, inplace=True)
    
races_pd = races_pd[["raceId","round","circuitId","name","year", "match_country"]].set_index(["match_country", "year"])
tyre_strategy_pd.set_index(["match_country", "year"], inplace=True)

tyre_strategy_with_id = tyre_strategy_pd.join(races_pd, how="left", rsuffix="_x")

# %%
tyre_strategy_with_id.rename(columns={
    "Stint 1 tyre_type" : "stint_1_tyre", 
    'Stint 1 lap_to'    : "stint_1",
    'Stint 2 tyre_type' : "stint_2_tyre", 
    'Stint 2 lap_to'    : "stint_2", 
    'Stint 3 tyre_type' : "stint_3_tyre",
    'Stint 3 lap_to'    : "stint_3", 
    'Stint 4 tyre_type' : "stint_4_tyre", 
    'Stint 4 lap_to'    : "stint_4",
    'Stint 5 tyre_type' : "stint_5_tyre", 
    'Stint 5 lap_to'    : "stint_5",
    'Stint 6 tyre_type' : "stint_6_tyre",
    'Stint 6 lap_to'    : "stint_6", 
    'Stint 7 tyre_type' : "stint_7_tyre", 
    'Stint 7 lap_to'    : "stint_7"
    }, inplace=True)

# %%
tyre_strategy_with_id.to_csv(join("data","outputs", "tyre_strategy_with_id_plus_2022.csv"))

# %%
tyre_strategy_with_id.reset_index(inplace=True)

# %%
tyre_strategy_with_id.shape
# Out:
# (3897, 23)

# %%
tyre_strategy_with_id_for_review = []
for stint in range(1, 8):
    tyre_strategy_with_id[f'stint_{stint}_tyre'] = tyre_strategy_with_id[f'stint_{stint}_tyre'].str.lower()
    df_auxiliar = tyre_strategy_with_id[["match_country","year",f'stint_{stint}_tyre']]
    df_auxiliar = df_auxiliar.rename(columns={f'stint_{stint}_tyre' : "tyre"})
    tyre_strategy_with_id_for_review.append(df_auxiliar)

tyre_strategy_with_id_for_review = pd.concat(tyre_strategy_with_id_for_review)
tyre_strategy_with_id_for_review = tyre_strategy_with_id_for_review.dropna()
#tyre_strategy_with_id_for_review = tyre_strategy_with_id_for_review[tyre_strategy_with_id_for_review["tyre"] != "wet"]
#tyre_strategy_with_id_for_review = tyre_strategy_with_id_for_review[tyre_strategy_with_id_for_review["tyre"] != "intermediate"]

# %%
tyre_strategy_with_id_for_review
# Out:
#                     match_country  year    tyre
# 0     70th anniversary grand prix  2020      c2
# 1     70th anniversary grand prix  2020      c3
# 2     70th anniversary grand prix  2020      c3
# 3     70th anniversary grand prix  2020      c3
# 4     70th anniversary grand prix  2020      c3
# ...                           ...   ...     ...
# 2139         hungarian grand prix  2020      c2
# 2640         malaysian grand prix  2014    hard
# 3457           spanish grand prix  2013  medium
# 1982            german grand prix  2019      c4
# 1983            german grand prix  2019      c4
#
# [10431 rows x 3 columns]

# %%
# combinaciones unicas de neumaticos en todas las carreras
map_to_tyres_combinations = pd.DataFrame(tyre_strategy_with_id_for_review \
        .drop_duplicates() \
        .sort_values(by="tyre") \
        .groupby(["match_country","year"])['tyre'] \
        .apply(','.join)).reset_index()

# %%
map_to_tyres_combinations

# %%
tyre_strategy_with_id.set_index(["match_country","year"], inplace=True)
map_to_tyres_combinations.set_index(["match_country","year"], inplace=True)

tyre_strategy_df_to_merge = tyre_strategy_with_id.join(map_to_tyres_combinations, how="left", rsuffix="_x")

# %%
mapper = {
    'c2,c3,c4': {'c2':'hard', 'c3':'medium', 'c4':'soft'},
    'medium,soft': {'soft':'soft', 'medium':'medium'},
    'soft,super soft,ultra soft': {'super soft':'soft', 'ultra soft':'medium', 'soft':'hard'},
    'super soft,ultra soft': {'super soft':'soft', 'ultra soft':'medium'},
    'hyper soft,super soft,ultra soft': {'hyper soft':'soft', 'super soft':'medium', 'ultra soft':'hard'},
    'c3,c4,c5' : {'c5':'soft','c4':'medium','c3':'hard'},
    'medium,super soft' :  {'super soft':'soft','medium':'medium'},
    'medium,soft,super soft' :  {'super soft':'soft','soft':'medium','medium':'hard'},
    'c2,c3,c5' :  {'c5':'soft','c3':'medium','c2':'hard'},
    'soft,super soft' :  {'super soft':'soft','soft':'medium'},
    'c3,c4' :  {'c4':'soft','c3':'medium'},
    'hard,medium' :  {'medium':'medium','hard':'hard'},
    'c1,c2,c3' :  {'c3':'soft','c2':'medium','c1':'hard'},
    'c2,c3' :  {'c3':'soft','c2':'medium'},
    'hard,intermediate,medium,wet' :  {'medium':'medium','hard':'hard'},
    'intermediate,wet' :  {'soft':'soft'},
    'hard,soft' :  {'soft':'soft','hard':'hard'},
    'intermediate,medium,soft,wet' :  {'soft':'soft','medium':'medium','':'hard'},
    'hyper soft,medium,soft' :  {'hyper soft':'soft','soft':'medium','medium':'hard'},
    'medium,soft,ultra soft' :  {'ultra soft':'soft','soft':'medium','medium':'hard'},
    'c3,c4,intermediate,wet' :  {'c4':'soft','c3':'medium'},
    'c2,c3,c4,intermediate' :  {'c4':'soft','c3':'medium','c2':'hard'},
    'intermediate,medium,soft,ultra soft,wet' :  {'ultra soft':'soft','soft':'medium','medium':'hard'},
    'intermediate,medium,soft' :  {'soft':'soft'},
    'hard,medium,soft' :  {'soft':'soft','medium':'medium','hard':'hard'},
    'hard,intermediate,medium' :  {'soft':'soft','medium':'medium','hard':'hard'},
    'intermediate,soft,super soft' :  {'super soft':'soft','soft':'medium'},
    'intermediate,soft,super soft,ultra soft,wet' :  {'super soft':'soft','ultra soft':'medium','soft':'hard'},
    'c3,c4,c5,intermediate,wet' :  {'c5':'soft','c4':'medium','c3':'hard'},
    'hyper soft,soft,ultra soft' :  {'hyper soft':'soft','ultra soft':'medium','soft':'hard'},
    'c3,c4,c5,intermediate' :  {'c5':'soft','c4':'medium','c3':'hard'},
    'c3,intermediate' :  {'c3':'medium'}
}

# %%
#tyre_strategy_df_to_merge.reset_index(inplace=True)
concatenate_me = []
for raceId in tyre_strategy_df_to_merge.raceId.unique():
    try:
        race_to_modify = tyre_strategy_df_to_merge[tyre_strategy_df_to_merge["raceId"] == raceId]
        instantiate_mapper = mapper[race_to_modify["tyre"][0]]
        concatenate_me.append(tyre_strategy_df_to_merge[tyre_strategy_df_to_merge["raceId"] == raceId].replace(instantiate_mapper))
    except:
        print(raceId)

tyre_strategy_normalized = pd.concat(concatenate_me)
tyre_strategy_normalized = tyre_strategy_normalized.reset_index()

# %%
tyre_strategy_normalized.shape
# Out:
# (3897, 24)

# %% [markdown]
# ### Tyre strategies as numerical

# %% [markdown]
# Here I will prepare the data to be expressed as columns with numbers: every columns contain the stint (number of laps) for the stint-number-tire-type column

# %%
tyre_strategy_normalized.columns
# Out:
# Index(['match_country', 'year', 'race', 'name', 'stint_1_tyre', 'stint_1',
#        'stint_2_tyre', 'stint_2', 'stint_3_tyre', 'stint_3', 'stint_4_tyre',
#        'stint_4', 'stint_5_tyre', 'stint_5', 'stint_6_tyre', 'stint_6',
#        'stint_7_tyre', 'stint_7', 'driverId', 'raceId', 'round', 'circuitId',
#        'name_x', 'tyre'],
#       dtype='object')

# %%
df = pd.DataFrame()

for i in tyre_strategy_normalized.index:
     row = tyre_strategy_normalized.loc[i]

     for n in range(1,8):
          
          df.loc[i, f"stint_{n}_{row[f'stint_{n}_tyre']}"] = row[f"stint_{n}"]
          for c in ['match_country', 'year', 'race', 'name', 'driverId', 'raceId', 'round', 'circuitId','name', 'tyre']:
               df.loc[i, c] = row[c]

# %%
df_tyre_stint_as_cat = df.copy()
df_tyre_stint_as_cat = df_tyre_stint_as_cat.astype({'year':'int64', 'driverId': 'int64', 'raceId':'int64', 'round':'int64', 'circuitId':'int64'})

for n in range(1,8):
    df_tyre_stint_as_cat.drop(columns = f"stint_{n}_nan", axis=1, inplace=True)

# %%
df_tyre_stint_as_cat.to_csv(join("data","outputs", "tyre_strategy_normalized_and_numeric_plus_2022.csv"))

# %%
tyre_strategy_normalized.reset_index(inplace=True)

# %%
tyre_strategy_normalized.to_csv(join("data","outputs", "tyre_strategy_normalized_plus_2022.csv"))

# %%
# combinaciones unicas de neumaticos en todas las carreras
tyre_strategy_with_id_for_review \
        .drop_duplicates() \
        .sort_values(by="tyre") \
        .groupby(["match_country","year"])['tyre'] \
        .apply(','.join) \
        .reset_index()["tyre"] \
        .unique()
# Out:
# array(['c2,c3,c4', 'medium,soft', 'soft,super soft,ultra soft',
#        'super soft,ultra soft', 'hyper soft,super soft,ultra soft',
#        'c3,c4,c5', 'medium,super soft', 'medium,soft,super soft',
#        'c2,c3,c5', 'soft,super soft', 'c3,c4', 'hard,medium', 'c1,c2,c3',
#        'c2,c3', 'hard,intermediate,medium,wet', 'intermediate,wet',
#        'hard,soft', 'intermediate,medium,soft,wet',
#        'hyper soft,medium,soft', 'medium,soft,ultra soft',
#        'c3,c4,intermediate,wet', 'c2,c3,c4,intermediate',
#        'intermediate,medium,soft,ultra soft,wet',
#        'intermediate,medium,soft', 'hard,medium,soft',
#        'hard,intermediate,medium', 'intermediate,soft,super soft',
#        'intermediate,soft,super soft,ultra soft,wet',
#        'c3,c4,c5,intermediate,wet', 'hyper soft,soft,ultra soft',
#        'c3,c4,c5,intermediate', 'c3,intermediate'], dtype=object)

# %%
soup = get_HTLM_from_file("2018-abu-dhabi-grand-prix-interactive-data-lap-charts-times-and-tyres.HTML", "data/tyre_strategy_racefans/2018_tyre_strategy")
tables = soup.find_all("table", {"class": "thin"})
for table in tables:

        ths = table.find_all("th")
        if len(ths) !=0:
            dict_keys = [th.text for th in ths]
            print(dict_keys)

# %%
get_tyre_strategy_table(soup)

# %%
def tyres_df_per_race(html_df):
    
    for stint in html_df.columns[1:]:

        html_df[f"stint_laps_{stint}"] = pd.to_numeric(html_df[stint].str.split("(", expand=True)[1].str.strip(")"))
        html_df[stint] = html_df[stint].str.split("(", expand=True)[0]

        html_df.rename(columns={"Unnamed: 0": "drivers"}, inplace=True)
        html_df.set_index("drivers", inplace=True)
        html_df.dropna(axis = 0, how = 'all', inplace = True)
        html_df.reset_index(inplace=True)
    
    tyre_per_lap = []
    for n in range(1, 53):
        tyre_per_lap.append(pd.DataFrame(columns=['drivers', 'lap', 'tyre_type'], data = {"drivers":html_df.drivers.values, 'lap':n}))

    tyre_per_lap = pd.concat(tyre_per_lap)
    
    columns = int((html_df.shape[1] - 1)/2)
    for i in html_df.index:
        row = html_df.loc[i]

        last_lap = 0
        for stint in range(1,columns + 1):
            laps = row[f'stint_laps_Stint {stint}']
            driver = row['drivers']
            tyre_type = row[f'Stint {stint}']

            if np.isnan(laps):
                continue

            tyre_per_lap.loc[(tyre_per_lap['drivers'] == driver) & (tyre_per_lap['lap'].isin(range(last_lap + 1, int(last_lap + laps) + 1))), 'tyre_type'] = tyre_type
            last_lap = int(last_lap + laps)
            
    tyre_per_lap = tyre_per_lap.set_index(["drivers","lap"])
    return tyre_per_lap

# %%
pd.read_html('./data/circuits_HTML/autodromo-jose-carlos-pace-carlos-pace-interlagos-circuit-information.HTML')[0]
# Out:
#                                  0  \
# 0                         Lap data
# 1                       Lap length
# 2                        Race laps
# 3                    Race distance
# 4                    Pole position
# 5                      Lap record*
# 6                      Fastest lap
# 7                    Maximum speed
# 8   Distance from grid to turn one
# 9                  Car performance
# 10                   Full throttle
# 11        Longest flat-out section
# 12                 Downforce level
# 13            Gear changes per lap
# 14                Fuel use per lap
# 15    Time penalty per lap of fuel
# 16                        Strategy
# 17              Pit lane time loss
# 18                  Tyre compounds
#
#                                                     1
# 0                                            Lap data
# 1                               4.309km (2.677 miles)
# 2                                                  71
# 3                           305.909km (190.083 miles)
# 4                        Right-hand side of the track
# 5                 1’11.473 (Juan Pablo Montoya, 2004)
# 6   1’07.281 (Lewis Hamilton, 2018, qualifying three)
# 7                                331kph (205.674 mph)
# 8                                                195m
# 9                                     Car performance
# 10                                                64%
# 11                                             1,394m
# 12                                               High
# 13                                                 36
# 14                                             1.35kg
# 15                                             0.042s
# 16                                           Strategy
# 17                                              18.6s
# 18                                        C2, C3,C C4
